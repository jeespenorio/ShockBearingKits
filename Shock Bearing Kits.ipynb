# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04323'],
    
    'AD ITem Number':['128244'],
    
    'Vendor Notes':['REAR UPPER'],
}

#Lists of Models
list_models = [


'KFX450R'

]
#Range of Years
years = list(range(2008, 2015))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make    Model Vendor Code                    Vendor Name       MPN  \
# 0  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 1  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 2  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 3  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 4  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 5  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
# 6  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04323
#
#   AD ITem Number Vendor Notes  Year
# 0         128244   REAR UPPER  2008
# 1         128244   REAR UPPER  2009
# 2         128244   REAR UPPER  2010
# 3         128244   REAR UPPER  2011
# 4         128244   REAR UPPER  2012
# 5         128244   REAR UPPER  2013
# 6         128244   REAR UPPER  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04324'],
    
    'AD ITem Number':['128245'],
    
    'Vendor Notes':['REAR UPPER'],
}

#Lists of Models
list_models = [


'YFM350X Warrior',
'YFZ350 Banshee',
'YFM660R Raptor'

  


]
#Range of Years
years = list(range(1987, 2010))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make            Model Vendor Code                    Vendor Name  \
# 0   atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# ..      ...              ...         ...                            ...
# 64  atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 65  atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 66  atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 67  atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 68  atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#          MPN AD ITem Number Vendor Notes  Year
# 0   AT-04324         128245   REAR UPPER  1987
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\2.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04360'],
    
    'AD ITem Number':['128248'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'YFM350X Warrior',
'YFZ350 Banshee',
'YFM660R Raptor'

  


]
#Range of Years
years = list(range(1987, 2010))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make            Model Vendor Code                    Vendor Name  \
# 0   atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# ..      ...              ...         ...                            ...
# 64  atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 65  atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 66  atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
# 67  atv/utv   YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 68  atv/utv   YFM660R Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#          MPN AD ITem Number Vendor Notes  Year
# 0   AT-04360         128248   REAR LOWER  1987
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\3.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04361'],
    
    'AD ITem Number':['128249'],
    
    'Vendor Notes':['REAR UPPER'],
}

#Lists of Models
list_models = [


'KFX700'

  


]
#Range of Years
years = list(range(2004, 2010))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make   Model Vendor Code                    Vendor Name       MPN  \
# 0  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
# 1  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
# 2  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
# 3  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
# 4  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
# 5  atv/utv  KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04361
#
#   AD ITem Number Vendor Notes  Year
# 0         128249   REAR UPPER  2004
# 1         128249   REAR UPPER  2005
# 2         128249   REAR UPPER  2006
# 3         128249   REAR UPPER  2007
# 4         128249   REAR UPPER  2008
# 5         128249   REAR UPPER  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\4.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04362'],
    
    'AD ITem Number':['128250'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'YFM700 Raptor'

  


]
#Range of Years
years = list(range(2006, 2018))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make          Model Vendor Code                    Vendor Name  \
# 0   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#          MPN AD ITem Number Vendor Notes  Year
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\5.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04363'],
    
    'AD ITem Number':['128251'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'YFM700 Raptor',
'YFZ450',
'YFZ450R',
'YFZ450X'


  


]
#Range of Years
years = list(range(2004, 2018))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make          Model Vendor Code                    Vendor Name  \
# 0   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv         YFZ450        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv        YFZ450R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv        YFZ450X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   atv/utv         YFZ450        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   atv/utv        YFZ450R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   atv/utv        YFZ450X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   atv/utv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   atv/utv         YFZ450        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  atv/utv        YFZ450R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  atv/utv        YFZ450X        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\6.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04364'],
    
    'AD ITem Number':['128252'],
    
    'Vendor Notes':['FRONT UPPER; FRONT LOWER'],
}

#Lists of Models
list_models = [


'LT-R450 QuadRacer'

  


]
#Range of Years
years = list(range(2006, 2012))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make              Model Vendor Code                    Vendor Name  \
# 0  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD ITem Number              Vendor Notes  Year
# 0  AT-04364         128252  FRONT UPPER; FRONT LOWER  2006
# 1  AT-04364         128252  FRONT UPPER; FRONT LOWER  2007
# 2  AT-04364         128252  FRONT UPPER; FRONT LOWER  2008
# 3  AT-04364         128252  FRONT UPPER; FRONT LOWER  2009
# 4  AT-04364         128252  FRONT UPPER; FRONT LOWER  2010
# 5  AT-04364         128252  FRONT UPPER; FRONT LOWER  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\7.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04365'],
    
    'AD ITem Number':['128253'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'TRX400EX Sportrax'


  


]
#Range of Years
years = list(range(1999, 2005))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make              Model Vendor Code                    Vendor Name  \
# 0  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD ITem Number Vendor Notes  Year
# 0  AT-04365         128253   REAR LOWER  1999
# 1  AT-04365         128253   REAR LOWER  2000
# 2  AT-04365         128253   REAR LOWER  2001
# 3  AT-04365         128253   REAR LOWER  2002
# 4  AT-04365         128253   REAR LOWER  2003
# 5  AT-04365         128253   REAR LOWER  2004

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\8.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04366'],
    
    'AD ITem Number':['128254'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'KVF650 Prairie 4x4',
'KFX700'



  


]
#Range of Years
years = list(range(2002, 2010))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make               Model Vendor Code                    Vendor Name  \
# 0   atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv              KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv              KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   atv/utv              KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   atv/utv              KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   atv/utv              KFX700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  atv/utv  KVF650 Prairie 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\9.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04367'],
    
    'AD ITem Number':['128255'],
    
    'Vendor Notes':['FRONT LOWER; REAR LOWER'],
}

#Lists of Models
list_models = [


'KVF650 Prairie 4x4',
'KFX700',
'KVF650 Brute Force 4x4',
'KVF650 Brute Force 4x4i',
'KVF650 Prairie 4x4',
'KV750 Brute Force 4x4i'




  


]
#Range of Years
years = list(range(2005, 2023))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                    Model Vendor Code  \
# 0    atv/utv       KVF650 Prairie 4x4        NACH
# 1    atv/utv                   KFX700        NACH
# 2    atv/utv   KVF650 Brute Force 4x4        NACH
# 3    atv/utv  KVF650 Brute Force 4x4i        NACH
# 4    atv/utv       KVF650 Prairie 4x4        NACH
# ..       ...                      ...         ...
# 103  atv/utv                   KFX700        NACH
# 104  atv/utv   KVF650 Brute Force 4x4        NACH
# 105  atv/utv  KVF650 Brute Force 4x4i        NACH
# 106  atv/utv       KVF650 Prairie 4x4        NACH
# 107  atv/utv   KV750 Brute Force 4x4i        NACH
#
#                        Vendor Name       MPN AD ITem Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# 3    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\10.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04367'],
    
    'AD ITem Number':['128255'],
    
    'Vendor Notes':['FRONT LOWER; REAR LOWER'],
}

#Lists of Models
list_models = [


'KVF650 Brute Force 4x4',
'KVF650 Brute Force 4x4i',
'KVF650 Prairie 4x4',
'KVF750 Brute Force 4x4i',
'KVF750 Brute Force 4x4i EPS',
'KVF750 Brute Force 4x4i EPS Camo'


  
]
#Range of Years
years = list(range(2005, 2023))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                             Model Vendor Code  \
# 0    atv/utv            KVF650 Brute Force 4x4        NACH
# 1    atv/utv           KVF650 Brute Force 4x4i        NACH
# 2    atv/utv                KVF650 Prairie 4x4        NACH
# 3    atv/utv           KVF750 Brute Force 4x4i        NACH
# 4    atv/utv       KVF750 Brute Force 4x4i EPS        NACH
# ..       ...                               ...         ...
# 103  atv/utv           KVF650 Brute Force 4x4i        NACH
# 104  atv/utv                KVF650 Prairie 4x4        NACH
# 105  atv/utv           KVF750 Brute Force 4x4i        NACH
# 106  atv/utv       KVF750 Brute Force 4x4i EPS        NACH
# 107  atv/utv  KVF750 Brute Force 4x4i EPS Camo        NACH
#
#                        Vendor Name       MPN AD ITem Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-04367         128255
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\11.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04368'],
    
    'AD ITem Number':['128256'],
    
    'Vendor Notes':['FRONT LOWER'],
}

#Lists of Models
list_models = [


'KFX450R'



  
]
#Range of Years
years = list(range(2008, 2015))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make    Model Vendor Code                    Vendor Name       MPN  \
# 0  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 1  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 2  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 3  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 4  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 5  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
# 6  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  AT-04368
#
#   AD ITem Number Vendor Notes  Year
# 0         128256  FRONT LOWER  2008
# 1         128256  FRONT LOWER  2009
# 2         128256  FRONT LOWER  2010
# 3         128256  FRONT LOWER  2011
# 4         128256  FRONT LOWER  2012
# 5         128256  FRONT LOWER  2013
# 6         128256  FRONT LOWER  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\12.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04369'],
    
    'AD ITem Number':['128257'],
    
    'Vendor Notes':['FRONT LOWER'],
}

#Lists of Models
list_models = [


'DVX 400',
'DVX 400 TS',
'KFX400',
'LT-Z400 QuadSport Z',
'LT-Z400 QuadSport Z LE'


  
]
#Range of Years
years = list(range(2003, 2015))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                   Model Vendor Code  \
# 0   atv/utv                 DVX 400        NACH
# 1   atv/utv              DVX 400 TS        NACH
# 2   atv/utv                  KFX400        NACH
# 3   atv/utv     LT-Z400 QuadSport Z        NACH
# 4   atv/utv  LT-Z400 QuadSport Z LE        NACH
# 5   atv/utv                 DVX 400        NACH
# 6   atv/utv              DVX 400 TS        NACH
# 7   atv/utv                  KFX400        NACH
# 8   atv/utv     LT-Z400 QuadSport Z        NACH
# 9   atv/utv  LT-Z400 QuadSport Z LE        NACH
# 10  atv/utv                 DVX 400        NACH
# 11  atv/utv              DVX 400 TS        NACH
# 12  atv/utv                  KFX400        NACH
# 13  atv/utv     LT-Z400 QuadSport Z        NACH
# 14  atv/utv  LT-Z400 QuadSport Z LE        NACH
# 15  atv/utv                 DVX 400        NACH
# 16  atv/utv              DVX 400 TS        NACH
# 17  atv/utv                  KFX400        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\13.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04369'],
    
    'AD ITem Number':['128257'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'TRX400EX Sportrax',
'TRX400X'



  
]
#Range of Years
years = list(range(2008, 2015))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make              Model Vendor Code                    Vendor Name  \
# 0   atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  atv/utv  TRX400EX Sportrax        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  atv/utv            TRX400X        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\15_Section 04 - Shock Bearing Kits (10-14-22)\Merge\14.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init Data
data1 = {
    'Make':['atv/utv'],
    'Model':['all model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-04369'],
    
    'AD ITem Number':['128257'],
    
    'Vendor Notes':['REAR LOWER'],
}

#Lists of Models
list_models = [


'TRX400EX Sportrax',
'TRX400X'



  
]
#Range of Years
years = list(range(2008, 2015))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all Dataframes
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
